# %% [markdown]
# ## Graficos de velocidad y frecuencia para 4 eventos de daño característicos
#
# Aqui se representan graficamente las señales en el dominio del tiempo y de la frecuencia para 4 casos caracteristicos de daño (primero cuarto del pilote, segundo cuarto, tercer cuarto y ultimo cuarto).

# %%
import pandas as pd
import numpy as np
import variables
from variables import generate_up, plot_up, transformada_fourier, plot_fourier

# %%
dataset = pd.read_csv("dataset/matriz_v1.csv").iloc[:,2:]

# %%
caso_1 = dataset.iloc[0]
caso_2 = dataset.iloc[15]
caso_3 = dataset.iloc[31]
caso_4 = dataset.iloc[63]

# %%
caso_1_up = generate_up(np.array(caso_1))
caso_2_up = generate_up(np.array(caso_2))
caso_3_up = generate_up(np.array(caso_3))
caso_4_up = generate_up(np.array(caso_4))

# %%
plot_up(np.array(caso_1_up))
plot_up(np.array(caso_2_up))
plot_up(np.array(caso_3_up))
plot_up(np.array(caso_4_up))

# %%
caso_1_freq = plot_fourier(np.array(caso_1_up))
caso_2_freq = plot_fourier(np.array(caso_2_up))
caso_3_freq = plot_fourier(np.array(caso_3_up))
caso_4_freq = plot_fourier(np.array(caso_4_up))
# Out:
# C:\Users\USUARIO\anaconda3\envs\Puente\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\USUARIO\anaconda3\envs\Puente\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\USUARIO\anaconda3\envs\Puente\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\USUARIO\anaconda3\envs\Puente\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ...

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import math 
  
x = np.linspace(-10, 10, 100) 
z = 1/(1 + np.exp(-x)) 
  
plt.plot(x, z) 
plt.xlabel("x") 
plt.ylabel("Sigmoid(X)")
plt.axhline(0, color="black", alpha=0.3)
plt.axvline(0, color="black", alpha=0.3)
  
plt.show()
